# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
raw_data = pd.read_json('reviews_Clothing_Shoes_and_Jewelry_5.json', lines=True)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278677 entries, 0 to 278676
# Data columns (total 9 columns):
# asin              278677 non-null object
# helpful           278677 non-null object
# overall           278677 non-null int64
# reviewText        278677 non-null object
# reviewTime        278677 non-null object
# reviewerID        278677 non-null object
# reviewerName      278225 non-null object
# summary           278677 non-null object
# unixReviewTime    278677 non-null int64
# dtypes: int64(2), object(7)
# memory usage: 19.1+ MB

# %%
is_2 = raw_data['overall'] == 1
rd_2 = raw_data[is_2]
rd_2


#for row in range(len(raw_data['overall'])):
#    if raw_data[row]['overall'] == 2:
#        print(reviewText)
# Out:
#               asin   helpful  overall  \
# 17      0000031887    [0, 0]        1
# 33      1608299953  [24, 31]        1
# 70      B00001WRHJ    [0, 2]        1
# 113     B00004SR9P    [2, 5]        1
# 129     B00004U1J2    [2, 3]        1
# 151     B00005JHKE    [0, 0]        1
# 338     B0000722HK   [6, 15]        1
# 357     B000072UMJ    [0, 5]        1
# 362     B000072UMJ    [0, 4]        1
# 374     B000072UMJ   [0, 10]        1
# 479     B000074RL3    [2, 4]        1
# 560     B00007GDAL    [2, 3]        1
# 602     B00007IVVR    [1, 2]        1
# 614     B000086211    [1, 2]        1
# 616     B000086211    [1, 2]        1
# 617     B000086211    [0, 1]        1
# 655     B0000865II    [0, 0]        1
# 670     B000086778    [1, 1]        1
# 706     B0000867GG    [1, 1]        1
# 714     B0000867ON    [2, 3]        1
# 719     B0000868O9    [2, 2]        1
# 729     B0000868O9    [4, 7]        1
# 744     B0000868O9    [1, 3]        1
# 752     B0000868O9    [1, 2]        1
# 772     B0000868O9    [2, 3]        1
# 804     B000086910    [2, 2]        1
# 813     B000086910    [0, 0]        1
# 877     B0000869QI    [1, 2]        1
# 897     B0000891IO    [0, 0]        1
# 906     B0000891IO   [0, 13]        1
# ...            ...       ...      ...
# 278161  B00IXCRK8C    [0, 0]        1
# 278163  B00IXCRK8C    [0, 0]        1
# 278179  B00IYF4QSA    [0, 0]        1
# 278236  B00J2ITY62    [0, 0]        1
# 278242  B00J2K98WA    [2, 2]        1
# 278246  B00J2L4EUA  [15, 17]        1
# 278247  B00J2L4EUA    [0, 0]        1
# 278248  B00J2L4EUA    [0, 0]        1
# 278256  B00J2L4EUA    [3, 3]        1
# 278270  B00J2QHKBA    [1, 1]        1
# 278277  B00J2S3ZKS    [4, 5]        1
# 278278  B00J2S3ZKS    [0, 0]        1
# 278279  B00J2S3ZKS    [0, 0]        1
# 278316  B00J54ZCA0    [4, 5]        1
# 278353  B00J8IDFU2    [0, 0]        1
# 278374  B00JB2IZ7I    [1, 1]        1
# 278405  B00JBW2TTI    [6, 6]        1
# 278435  B00JDPRJAM    [0, 0]        1
# 278466  B00JDU6W5A    [0, 0]        1
# 278474  B00JE87N40    [2, 3]        1
# 278476  B00JE87N40    [0, 0]        1
# 278477  B00JE87N40    [1, 1]        1
# 278478  B00JE87N40    [0, 0]        1
# 278496  B00JG4SU80    [0, 0]        1
# 278579  B00JWI8YQ8    [0, 0]        1
# 278580  B00JWI8YQ8    [3, 3]        1
# 278581  B00JWI8YQ8    [0, 0]        1
# 278588  B00JWRMQEU    [0, 0]        1
# 278645  B00KA602SY    [0, 0]        1
# 278651  B00KCWMG5S    [1, 1]        1
#
#                                                reviewText   reviewTime  \
# 17      Never GOT this item - but gave a 1 STAR becaus...  05 12, 2014
# 33      I bought this product a little over a year ago...  09 21, 2012
# 70      Have they lost their minds??!! Over 100$ for a...  09 19, 2013
# 113     This would have worked fine if the buckles had...  07 30, 2013
# 129     I ordered the jet pack for my 6 year old grand...   11 6, 2011
# 151     Yelp, I guarantee this costume will rip on the...  02 22, 2011
# 338     Great fabric and tight fit.  Problem is that i...  02 25, 2011
# 357     El vendedor debe revisar las opciones, Me envi...  01 27, 2013
# 362     These shoes run so big, and the size is very c...  01 12, 2013
# 374     I did not know that Converse stooped that low ...   02 8, 2013
# 479     again, i bought this based on a recommendation...  03 21, 2013
# 560     The card slots in the wallet are too tight.  Y...  12 25, 2012
# 602     Large chest women cannot wear theses.You know ...  09 21, 2012
# 614     I am a 38D in all bras, Victoria Secret, Playt...  10 22, 2012
# 616     Bought a 40DDD. This bra is offensively ugly a...  11 22, 2012
# 617     The bra fits well but the cups are far larger ...  06 23, 2013
# 655     I ordred Queen size....It looks like my child'...  05 16, 2014
# 670     This is a great idea, but they are very hard t...   01 2, 2013
# 706     Truly terrible.  I purchased two of the three ...  01 14, 2014
# 714     Well I guess thy r ok but the stockings had a ...  04 28, 2012
# 719     I normally wear a 42 B but I had to buy a C in...   12 3, 2013
# 729     I was looking for a casual bra to wear when I ...   07 1, 2010
# 744     Itchy, pointy, and VERY uncomfortable! How in ...   11 6, 2013
# 752     Wow...I should have listened to the other revi...   07 3, 2013
# 772     I doubt anyone's body is this shape, or that a...  08 29, 2011
# 804     Not the bra for large breasted women unless yo...   01 9, 2014
# 813     First off it fits way too small. I bought it b...   05 3, 2014
# 877     This is too expensive for the cheap quality of...  06 30, 2013
# 897     I have had so many Hanes pantyhoses in c/d siz...  04 20, 2013
# 906     this style does not say if it is Sandalfoot or...  01 25, 2010
# ...                                                   ...          ...
# 278161  Wow, I have actually worked in the jewelry ind...   07 2, 2014
# 278163  Look really cheap, and one was missing a rhine...  06 22, 2014
# 278179        Cheap plastic I can buy at the dollar store   07 7, 2014
# 278236  Had to give it to my daughter that's wear a sm...   07 1, 2014
# 278242  Ordered a large, should have been a little big...  05 25, 2014
# 278246  This fits really odd.  Very tight on the arms ...  04 29, 2014
# 278247              way to close you can barley put it on   07 2, 2014
# 278248  Give it away I order a large and it look like ...   07 4, 2014
# 278256  Very thin and see through material. Really che...   06 4, 2014
# 278270  Would have been great if the clasp didn't brea...  05 14, 2014
# 278277  This was a such a pretty looking shirt in the ...   05 6, 2014
# 278278  he makes buying really hard, I have purchased ...  05 20, 2014
# 278279  I purchased the large, and there is no part of...  07 18, 2014
# 278316  I don't satisfy with this purchase or with the...  05 24, 2014
# 278353  If you know what is good for you do not buy th...  07 17, 2014
# 278374  I am 5'6' 183, with curves.  I thought the wra...  06 14, 2014
# 278405  I am so disappointed, I'm a BIG amazon shopper...   06 3, 2014
# 278435  This one size fits all up to 1X US is an absol...  06 17, 2014
# 278466  This si the only one size fits all product I r...  06 28, 2014
# 278474  I wear a size 6; I bought a medium; and couldn...  04 26, 2014
# 278476  Horribly cheap material. Short and fit funny. ...  06 28, 2014
# 278477  The material is similar to that of a rain coat...   05 7, 2014
# 278478  Fabric is uncomfortable like a Halloween costu...  07 22, 2014
# 278496                        Fabric is not what it seems  07 13, 2014
# 278579  I guess the model shown is flat chested. I ord...  06 30, 2014
# 278580  but it is impossible to wear this blouse is ve...  06 14, 2014
# 278581  This is at least 2 sizes smaller than advertiz...  07 13, 2014
# 278588  fit was too small. i think this is for an EL t...  05 21, 2014
# 278645  The shirt fits like a belly shirt...way too sm...   07 5, 2014
# 278651  Arrived with what looked like a bleach stain o...  06 23, 2014
#
#             reviewerID                          reviewerName  \
# 17      A2XJ13PIXVJFJH                   Myra MLH "Myra MLH"
# 33      A28QH3KX709FFQ                   Don Quixote "Don Q"
# 70      A3VZ1PO40JCGFV                            Tina Smith
# 113     A1QMRP6KLZDMAT             John J. Francis "rojac70"
# 129     A23GX78LIV4J2F                               Edith W
# 151      AJGN47OUGFDIT                            flyladyjax
# 338     A1PPDBGCKM9AM0        Skipper McFearson "quickcuda6"
# 357      AQZWB4Y038UL2                                 chono
# 362      AB470GAVSK9FJ                              Cupcakes
# 374     A2CDDKORD3XRBJ                              el viejo
# 479     A27P22K84E0A5X         P. Everett "elderlycaregiver"
# 560     A3IP2CILX99ABQ                             S. Milner
# 602      AV8DS9NWBS6P5                                Sherri
# 614     A2OFR7QCLQWCF7                              Newmommy
# 616     A372MRGDRTS413                        Raquel Edwards
# 617     A26KYZ3D2AQ4JL                        Richard George
# 655     A1VQSFKF00KOQ3                 janechild "janechild"
# 670      AYIPRFLIS6NFT                              Kawigirl
# 706     A18FEPC99HQHKR  morejamperhaps "Orbiting Supernovas"
# 714     A174X51AGFWAMW                                Sobela
# 719     A3PLZB0DZ3NZWW                             Amazon A.
# 729      AYOMAHLWRQHUG                  Conspicuous Consumer
# 744     A1NJ71X3YPQNQ9                               JBerger
# 752      A6FCCZY1UD4HL                          killercolors
# 772     A2AK480UW3Z2CK                                   T P
# 804     A3R2YNKIHFIERF                        Darlene Flores
# 813     A2ZO3ERY6GGLQJ             ...... "................"
# 877     A1E19ZBPXY24EJ                     M. Avery "Mavery"
# 897      ALFBROXVWTMS3                           Jili "Jili"
# 906     A1NR6O1GKR0UQS                          Natty Suarez
# ...                ...                                   ...
# 278161  A35YSVE9WCK0HY  Crystle Martinez "AWINC at its best"
# 278163   AEZQEGXH01DX5                        Monica Botello
# 278179  A239EZENHKFR10                        nadege antoine
# 278236  A1J74R1SB3MFN2                                Gisele
# 278242  A399L692UBOET7                                Olivia
# 278246  A384ASRM96SH7B                            Annonymous
# 278247  A269G9FDX6MLOM                        Brenda Salazar
# 278248  A1X4MEKFEQOP4N                      Carlethea Samuel
# 278256  A2YGGO09QI3BLL                             LoveLea20
# 278270   AJ0W5GUI55P0O                                Anomal
# 278277   A9B5K1WPK68IC                            jabeen ali
# 278278  A28CP3NHP3MUR7                                Nellie
# 278279  A2YJT693OQAH2L         Rikki B. Schwartz "zookeeper"
# 278316   A2OCGU5XFYTBU                                  Jina
# 278496                                      TOO TOO SMALL      1405209600
# 278579                        Pretty but not for everyone      1404086400
# 278580                                    fit as aspected      1402704000
# 278581                                       way to small      1405209600
# 278588                                    loved the style      1400630400
# 278645                  The shirt fits like a belly shirt      1404518400
# 278651                                            Stained      1403481600
#
# [11192 rows x 9 columns]

# %%
# Split words into new series
words = raw_data['reviewText'].str.lower().str.split('; |, |\*|\n')
#print(words)
#words.value_counts()
# Get amount of unique words
#unique_w = pd.DataFrame()

#unique_w['counter'] = words.apply(set).apply(len)

# Get amount of words
#df['LyricsWords'] = lyrics.apply(len)

#print(unique_w)

# %%
raw_data.reviewText.apply(lambda x: pd.value_counts(x.split("; |, |\*|\n"))).sum(axis = 0)

# %%
# Convert our label ('rating') from regression to a binary classifier using the mean value
# if rating is > mean then 1 else 0

rating_mean = raw_data.rating.mean()

raw_data.loc[raw_data.rating >= rating_mean, 'rating'] = 1
raw_data.loc[raw_data.rating > 1, 'rating'] = 0

# %%
# Drop the title column as it is a text data and does not contribute as a feature or label

raw_data.drop(['title'], axis=1, inplace=True)

# %%
# Fill any NaN values to zeros

raw_data.fillna(0, inplace=True)

# %%
# Create our feature set and label data

X = raw_data.drop(['rating'], axis=1)
y = raw_data['rating']

# %%
from sklearn.model_selection import train_test_split

# test_size: The split between test and train is 80-20 approximately

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/7.0, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Fit on training set only.
scaler.fit(X_train)

# Apply transform to both the training set and the test set.
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.decomposition import PCA

# Fit our scaled data into PCA with 30 components
pca = PCA(n_components=30)

pca.fit(X_train)
X_train_pca = pca.fit_transform(X_train)
print("original shape:   ", X_train.shape)
print("transformed shape:", X_train_pca.shape)
# Out:
# original shape:    (17187, 678)
# transformed shape: (17187, 30)

# %%
print(X_train_pca)
# Out:
# [[ 2.19464509 -0.42730286 -2.11842427 ...  0.05369374  0.45428909
#   -0.72683721]
#  [ 2.28295127 -1.40990691 -1.13247203 ... -0.27496712  0.18153246
#   -0.05967883]
#  [ 1.75110339 -2.32835176 -0.80778008 ... -0.70075763  0.90103192
#    0.27108729]
#  ...
#  [-2.67269813  4.20303803 -3.44893859 ... -0.2224622  -0.04603899
#    0.7233046 ]
#  [-2.44972786 -1.37460058  0.3467956  ... -1.87955194  1.23870871
#    0.96033072]
#  [-3.84252969 -0.98544941  1.07119709 ... -0.14116248 -0.26743568
#    0.46961689]]

# %%
from sklearn.svm import SVC
svr = SVC(gamma='auto')

svr.fit(X_train_pca, y_train)

predicted_labels = svr.predict(X_train_pca)
#plt.scatter(y_train, predicted_labels)

svr.score(X_train_pca, y_train)

from sklearn.model_selection import cross_val_score
cross_val_score(svr, X_train_pca, y_train, cv=5)
# Out:
# array([0.80919139, 0.80570099, 0.79924353, 0.80389875, 0.80797207])

# %%
# Check the confusion matrix to see fp and tp

from sklearn.metrics import confusion_matrix
confusion_matrix(y_train, predicted_labels)
# Out:
# array([[  836,  2744],
#        [   81, 13526]])

# %%
# Check the original labels

pd.Series(y_train).value_counts()
# Out:
# 1.0    13607
# 0.0     3580
# Name: rating, dtype: int64

# %%
# Check predicted labels

pd.Series(predicted_labels).value_counts()
# Out:
# 1.0    16270
# 0.0      917
# dtype: int64
